# %% [markdown]
# **질문 1.** [사과, 오렌지, 수박]의 가격이 각각 1200원, 2000원, 15000원입니다. 과일의 이름을 작성하면 가격을 알려주는 챗봇을 만들어 보세요.

# %%
Q = input()
fruits = {"사과":1200, "오렌지":2000, "수박":15000}
for fruit in fruits.keys():
    if fruit in Q:
        print(fruits[fruit])
# Out:
# 사과
# 1200

# %% [markdown]
# **질문 2.**“사과”, “가격” 이라는 단어가 포함된 문장을 입력받으면 가격을 알려주는 챗봇을 구현해 보세요.
# ex) “사과 가격이 얼마에요?”

# %%
Q = input()
fruits = {"사과":1200, "오렌지":2000, "수박":15000}
for fruit in fruits.keys():
  if fruit in Q:
    if "가격" in Q:
      print(fruits[fruit])
# Out:
# 사과 가격이 얼마에요?
# 1200

# %% [markdown]
# **질문 3.** 위의 기능이 구현된 fruit_price(Q) 함수를 만들어 호출해보세요.
# (인자 Q는 사용자의 input() 함수로 입력받은 문자열입니다.)

# %%
def fruit_price(Q):
  fruits = {"사과":1200, "오렌지":2000, "수박":15000}
  for fruit in fruits.keys():
    if fruit in Q:
      if "가격" in Q:
        print(fruits[fruit])

Q = input()
fruit_price(Q)
# Out:
# 사과 가격이 얼마에요?
# 1200

# %% [markdown]
# **질문 4.** price = fruit_price(fruit) 와 같이 과일의 이름을 넣으면 가격이 출력되어 price 변수에 담기도록 작성한 후 아래 print문이 출력되는지 확인하세요.
# print(f“요청하신 과일의 가격은 {price} 입니다.”)

# %%
def fruit_price(Q):
  fruits = {"사과":1200, "오렌지":2000, "수박":15000}
  for fruit in fruits.keys():
    if fruit in Q:
      if "가격" in Q:
        return fruits[fruit]

Q = input()
price = fruit_price(Q)
print(f"요청하신 과일의 가격은 {price}입니다.")
# Out:
# 오렌지의 가격은?
# 요청하신 과일의 가격은 2000입니다.

# %% [markdown]
# **질문 5.** 하나의 ‘+’ 연산자가 있을 때, 앞 뒤의 두 구문을 묶어서 반환하는 모듈을 개발하세요.

# %%
 def calculation(Q):
    first = ""
    second = ""
    firstNum = Q[:Q.index("+")]
    secondNum = Q[Q.index(first) + 1:]
 return first + second
