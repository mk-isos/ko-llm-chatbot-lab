# %% [markdown]
# **질문 1.**  spaCy를 활용하여 다음 문장을 품사 태깅을 해보세요.
#  “The way to get started is to quit talking and begin doing.”

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("The way to get started is to quit talking and begin doing.")

for token in doc:
    print(token.text, token.pos_)
# Out:
# The DET
# way NOUN
# to PART
# get AUX
# started VERB
# is AUX
# to PART
# quit VERB
# talking VERB
# and CCONJ
# begin VERB
# doing VERB
# . PUNCT

# %% [markdown]
# **질문 2.**  spaCy 라이브러리를 활용하여 위 문장의 표제어를 추출하세요.

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("The way to get started is to quit talking and begin doing.")

for token in doc:
    print(token.text, token.lemma_)
# Out:
# The the
# way way
# to to
# get get
# started start
# is be
# to to
# quit quit
# talking talk
# and and
# begin begin
# doing do
# . .

# %% [markdown]
# **질문 3.**  KoNLPy패키지 중 Kkma 형태소 분석기를 활용하여 다음 문장을 품사 태깅하세요.
#  “별을 노래하는 마음으로 모든 죽어가는 것을 사랑해야지.

# %%
# !pip install konlpy
from konlpy.tag import Kkma

# 텍스트 입력
text = "별을 노래하는 마음으로 모든 죽어가는 것을 사랑해야지."

 # Kkma 형태소 분석기 사용 예시
kkma = Kkma()
print("Kkma :", kkma.pos(text))
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 88.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 495.9/495.9 kB 30.1 MB/s eta 0:00:00
# ...
# Kkma : [('별', 'NNG'), ('을', 'JKO'), ('노래', 'NNG'), ('하', 'XSV'), ('는', 'ETD'), ('마음', 'NNG'), ('으로', 'JKM'), ('모든', 'NNP'), ('죽', 'VV'), ('어', 'ECD'), ('갈', 'VV'), ('는', 'ETD'), ('것', 'NNB'), ('을', 'JKO'), ('사랑', 'NNG'), ('하', 'XSV'), ('어야지', 'EFN'), ('.', 'SF')]

# %% [markdown]
# **질문 4.** Okt 형태소 분석기로 위 문장을 다음의 불용어 리스트를 활용하여 불용어를 제거하세요.
#  stopwords = ["을", "를", "이", "가", "은", "는", "에", "한", "하다"]

# %%
from konlpy.tag import Okt

okt = Okt()
text = "별을 노래하는 마음으로 모든 죽어가는 것을 사랑해야지."
tokens = okt.morphs(text)

stopwords = ["을", "를", "이", "가", "은", "는", "에", "한", "하다"]

filtered_tokens = [word for word in tokens if word not in stopwords]
print(filtered_tokens)
# Out:
# ['별', '노래', '하는', '마음', '으로', '모든', '죽어가는', '것', '사랑', '해야지', '.']

# %% [markdown]
# **질문 5.**  모듈Okt 모듈을 활용하여 문장을 입력하면 명사만 리스트로 반환하는 모듈을 만드세요.
#  ex) 나는 소년이다
# ['나', '소년']

# %%
from konlpy.tag import Okt

def getNouns(line):
    okt = Okt()
    results = okt.nouns(line)
    return results

getNouns('나는 소년이다')
# Out:
# ['나', '소년']
