# %% [markdown]
# **질문 1.** 리스트형 변수 sentence에 “Hello”, “ChatGPT” 라는 문자열을 입력하세요.

# %%
 sentence = ["Hello", "ChatGPT"]

# %% [markdown]
# **질문 2.** 반복문을 활용하여 sentence 변수를 3번 출력하세요.

# %%
for i in range(3):
       print(sentence)

# %% [markdown]
# **질문 3.** 2번의 코드를 Call이라는 이름의 함수로 만들어서 호출하세요.

# %%
def Call():
    for i in range(3):
        print(sentence)
 Call()

# %% [markdown]
# **질문 4.** 데이터프레임 타입의 score라는 변수에 인덱스가 철수, 영희, 민수이고 수학, 영어 점수를 각각 [80, 90], [50, 100], [70, 60]으로 할당하세요.

# %%
 import pandas as pd
 score = pd.DataFrame(data = [[80, 90], [50, 100], [70, 60]], columns=['수학', '영어'], index=['철수', '영희', '민수'])

# %% [markdown]
# **질문 5.** score 안의 값을 전치행렬로 출력하세요

# %%
 print(score.T)
