# %%
#한글 출력
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 24 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 0s (25.4 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'NanumGothic'

# %% [markdown]
# **질문 1.** 다음의 데이터를 matplotlib을 활용하여 제목을 '과일 무게와 칼로리'로 설정한 후 그려보세요.
# weight = [56, 25, 92, 172, 210]
# kcal = [48, 8, 82, 225, 227]

# %%
import pandas as pd

weight = [56, 25, 92, 172, 210]
kcal = [48, 8, 82, 225, 227]

plt.title('과일의 무게와 칼로리')
plt.scatter(weight, kcal)
plt.show()

# %% [markdown]
# **질문 2.** 1번의 그래프에서 마커는 빨간색상,  모양은 '+'로 설정하세요.
# 그래프의 x축과 y축 라벨을 각각 '과일 별 무게', '과일 별 칼로리' 로 설정해보세요.

# %%
import matplotlib.pyplot as plt

plt.title('과일의 무게와 칼로리')
plt.scatter(weight, kcal, marker='+', c='red')
plt.xlabel('과일 별 무게')
plt.ylabel('과일 별 칼로리')
plt.show()

# %% [markdown]
# **질문 3.** weight, kcal 데이터를 순서대로 고구마, 딸기, 바나나, 오렌지, 참외로 설정하고 범례를 우측 하단에 표시해 보세요.
# 마커와 컬러는 아래 리스트를 따라 출력되도록 하세요.
# marker_list = ['D', '+', '*', 'v', '^']
# color_list = ['blue', 'green', 'red', 'cyan', 'magenta']

# %%
import matplotlib.pyplot as plt

name = ['고구마', '딸기', '바나나', '오렌지', '참외']
marker_list = ['D', '+', '*', 'v', '^']
color_list = ['blue', 'green', 'red', 'cyan', 'magenta']

plt.title('과일의 무게와 칼로리')
for i in range(5):
  plt.scatter(weight[i], kcal[i], marker=marker_list[i], c=color_list[i], label=name[i])

plt.legend(loc = 'lower right')
plt.xlabel('과일 별 무게')
plt.ylabel('과일 별 칼로리')
plt.show()

# %% [markdown]
# **질문 4.** matplotlib에서 plt.text(x, y, label) 함수는 글씨를 삽입하는 함수입니다. 인수는 순서대로 텍스트의 x위치, y위치, 삽입할 문구입니다.
# 위 그래프에서 범례를 지우고 각각의 마커 위에 글씨가 나오도록 코드를 수정하세요.

# %%
import matplotlib.pyplot as plt

name = ['고구마', '딸기', '바나나', '오렌지', '참외']
marker_list = ['D', '+', '*', 'v', '^']
color_list = ['blue', 'green', 'red', 'cyan', 'magenta']

plt.title('과일의 무게와 칼로리')
for i in range(5):
  plt.scatter(weight[i], kcal[i], marker=marker_list[i], c=color_list[i], label=name[i])
  plt.text(weight[i]-5, kcal[i]+10, name[i]) #텍스트의 위치를 마커 가운데 위로 수정하기 위해 x 값에는 -5, y 값에는 +10을 더해줌

plt.ylim([0, 300])
#plt.legend(loc = 'lower right')
plt.xlabel('과일 별 무게')
plt.ylabel('과일 별 칼로리')
plt.show()

# %% [markdown]
# **질문 5.** x축을 위한 레이블 리스트와 y축을 위한 수칫값 리스트를 인수로 받으면 꺾은선 그래프를 그리는 모듈을 작성하세요.

# %%
import matplotlib.pyplot as plt

def showGraph(xList, yList):
 plt.plot(xList, yList, linestyle='solid', label='solid')
plt.show()
